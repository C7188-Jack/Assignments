# %%
name = str(input("Please enter your first name: ")).lower()

if name.isalpha():

    if (name == "jack"):

        print("Hello Jack. The password is: HelloWorld!")

    else: print("Hello %s! See you later."%name)

else: print("Invalid name. Try again please")
